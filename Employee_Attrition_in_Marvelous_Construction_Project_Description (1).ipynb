# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# 1. Load the provided CSV file into a Data Frame object named chatterbox.

# %%
chatterbox = pd.read_csv('employees.csv')

# %% [markdown]
# 2. Get an overview of the data:

# %%
# Display the first few rows of the DataFrame
print(chatterbox.head())

# Check the dimensions of the DataFrame
print(chatterbox.shape)

# Get summary statistics of the numerical columns
print(chatterbox.describe())

# Check the data types of the columns
print(chatterbox.dtypes)
# Out:
#    Employee_No  Employee_Code                 Name Title  Gender  Religion_ID  \
# 0          347              6    Myrl Bechtelar MD    Mr    Male            1
# 1          348             33         Francis Mraz    Mr    Male            1
# 2          349             53    Mr Emmet Blick Jr    Mr    Male            1
# 3          351             77  Mr Nelson Braun PhD    Ms  Female            4
# 4          352             88     Maximillian Hand    Mr    Male            1
#
#   Marital_Status  Designation_ID Date_Joined Date_Resigned    Status  \
# 0        Married              24   12/8/1993            \N    Active
# 1        Married              24   3/14/1995            \N    Active
# 2        Married              23   1/27/1988     6/28/2021  Inactive
# 3        Married              40   10/1/1999     1/31/2022  Inactive
# 4        Married               7   1/26/2001            \N    Active
#
#   Inactive_Date Reporting_emp_1 Reporting_emp_2 Employment_Category  \
# 0            \N              \N              \N               Staff
# 1            \N              \N              \N               Staff
# 2     6/28/2021              \N              \N               Staff
# 3     1/31/2022              \N              \N               Staff
# 4            \N              \N              \N               Staff
#
#   Employment_Type  Religion         Designation Year_of_Birth
# 0       Permanant  Buddhist              Driver          1965
# 1       Permanant  Buddhist              Driver          1973
# 2       Permanant  Buddhist       Account Clerk          1974
# 3       Permanant  Catholic  Purchasing Officer          1974
# 4       Permanant  Buddhist        Store Keeper          1980
# (997, 19)
#        Employee_No  Employee_Code  Religion_ID  Designation_ID
# count   997.000000   9.970000e+02   997.000000      997.000000
# mean   1433.159478   2.794296e+05     1.393180       48.504514
# std     770.821006   5.810717e+05     0.967272       43.112201
# min     347.000000   6.000000e+00     1.000000        1.000000
# 25%     728.000000   4.913000e+03     1.000000       27.000000
# 50%    1164.000000   5.387000e+03     1.000000       31.000000
# 75%    2197.000000   1.961360e+05     1.000000       55.000000
# max    3041.000000   1.985024e+06     5.000000      201.000000
# Employee_No             int64
# Employee_Code           int64
# Name                   object
# Title                  object
# Gender                 object
# Religion_ID             int64
# Marital_Status         object
# Designation_ID          int64
# Date_Joined            object
# Date_Resigned          object
# Status                 object
# Inactive_Date          object
# Reporting_emp_1        object
# Reporting_emp_2        object
# Employment_Category    object
# Employment_Type        object
# Religion               object
# Designation            object
# Year_of_Birth          object
# dtype: object

# %% [markdown]
# 3. Check for missing values:

# %%
chatterbox.head(50)
# Out:
#     Employee_No  Employee_Code                   Name Title  Gender  \
# 0           347              6      Myrl Bechtelar MD    Mr    Male
# 1           348             33           Francis Mraz    Mr    Male
# 2           349             53      Mr Emmet Blick Jr    Mr    Male
# 3           351             77    Mr Nelson Braun PhD    Ms  Female
# 4           352             88       Maximillian Hand    Mr    Male
# 5           353            155           Zena Nicolas    Mr    Male
# 6           354            181       Coralie Bernhard    Mr    Male
# 7           355            192              Josh Roob    Mr    Male
# 8           356            283           Ernest Upton    Ms  Female
# 9           359            529     Sydney Oberbrunner    Mr    Male
# 10          360            573         Angeline Yundt    Mr    Male
# 11          361            596  Prof Karlie Bauch III    Mr    Male
# 12          363            691       Leonel Romaguera    Mr    Male
# 13          365            759      Sidney Macejkovic    Mr    Male
# 14          366            900     Prof Jerod Pfeffer    Mr    Male
# 15          371           1084   Ignatius Volkman DDS    Ms  Female
# 16          372           1086        Doyle Hettinger    Mr    Male
# 17          373           1093           Izaiah Berge    Mr    Male
# 18          376           1154  Prof Arden Jacobs III    Mr    Male
# 19          377           1275  Shaylee Schroeder III    Mr    Male
# 20          378           1290          Raymond Bogan    Mr    Male
# 21          379           1329            Kayden Rice    Mr    Male
# 22          380           1336          Macey Simonis    Mr    Male
# 23          381           1373          Jayde Witting    Mr    Male
# 24          383           1405        Sylvan Gislason    Mr    Male
# 25          384           1425     Dr Kennedy Ryan MD    Mr    Male
# 26          385           1472    Tillman Greenfelder    Mr    Male
# 27          388           1573            Hanna Wyman    Mr    Male
# 28          389           1587           Tessie Fadel    Mr    Male
# 29          391           1610           Orval Hessel    Mr    Male
# 30          392           1620       Katelin Thompson    Mr    Male
# 31          393           1653         Savanna Spinka    Mr    Male
# 32          394           1730        Carley Bogisich    Mr    Male
# 33          396           1769         Jaquelin Block    Mr    Male
# 34          399           1870         Garland Feeney    Mr    Male
# 35          400           1872          Elody Waelchi    Mr    Male
# 36          401           1888             Nola Grant    Mr    Male
# 37          402           1900          Macie Kuvalis    Mr    Male
# 38          403           2009          Julie Osinski    Mr    Male
# 39          404           2026            Jody Stokes    Mr    Male
# 40          405           2034          Scottie Ratke    Mr    Male
# 41          407           2151       Braulio Pagac IV    Mr    Male
# 42          408           2186               Jon Kuhn    Mr    Male
# 43          410           2284          Ally Nikolaus    Mr    Male
# 44          411           2301      Jesus Dietrich Sr    Mr    Male
# 45          413           2313            Addie Purdy    Mr    Male
# 46          414           2333     Noelia Roberts DDS    Mr    Male
# 47          415           2334        Isabella Brakus    Mr    Male
# 48          416           2337          Bo Schaefer I    Mr    Male
# 49          419           2421          Ms Jany Lemke    Mr    Male
#
#     Religion_ID Marital_Status  Designation_ID Date_Joined Date_Resigned  \
# 0             1        Married              24   12/8/1993            \N
# 1             1        Married              24   3/14/1995            \N
# 2             1        Married              23   1/27/1988     6/28/2021
# 3             4        Married              40   10/1/1999     1/31/2022
# 4             1        Married               7   1/26/2001            \N
# 5             1        Married              22   9/29/2003            \N
# 6             1        Married              22  11/10/2003    0000-00-00
# 7             1        Married             126   2/16/2004            \N
# 8             1         Single              23    6/1/2005            \N
# 9             1        Married              41    7/1/2006     1/31/2022
# 10            1        Married              42   8/29/2006      5/5/2021
# 11            3         Single               7   11/1/2006    0000-00-00
# 12            1        Married              24   5/25/2007     5/23/2021
# 13            1        Married              43  11/12/2007            \N
# 14            1        Married              44  11/15/2008    0000-00-00
# 15            1         Single              45    8/2/2010     4/30/2021
# 16            1        Married              46    8/5/2010            \N
# 17            1        Married              35  10/26/2010    0000-00-00
# 18            1        Married               7   3/24/2011    0000-00-00
# 19            5         Single              48   11/3/2011            \N
# 20            1        Married              33  11/21/2011            \N
# 21            1         Single              27   1/25/2012            \N
# 22            1        Married              24   1/29/2012            \N
# 23            5        Married              22   3/17/2012            \N
# 24            1        Married              24   5/21/2012            \N
# 25            1        Married               8    6/5/2012            \N
# 26            1        Married              49    7/6/2012            \N
# 27            1        Married              22  11/18/2012            \N
# 28            1        Married              24  12/14/2012    0000-00-00
# 29            1        Married              37   1/24/2013            \N
# 30            5        Married              22    2/5/2013            \N
# 31            5        Married               6    4/1/2013            \N
# 32            1        Married              46   6/27/2013    12/17/2021
# 33            1         Single              67   8/21/2013            \N
# 34            3        Married              27   1/28/2014     8/31/2021
# 35            3         Single              27   1/24/2014    0000-00-00
# 36            1        Married               7   2/25/2014    0000-00-00
# 37            1         Single              24   2/22/2014    0000-00-00
# 38            1        Married              43    5/3/2014            \N
# 39            1         Single              36    6/4/2014    0000-00-00
# 40            1            NaN              27    6/9/2014    0000-00-00
# 41            3         Single               8   9/17/2014    0000-00-00
# 42            1         Single               8   10/1/2014    0000-00-00
# 43            1         Single              52    2/5/2015     5/30/2021
# 44            1        Married              24   4/28/2015    0000-00-00
# 45            1         Single              35    5/1/2015    0000-00-00
# 46            3         Single              54    6/2/2016            \N
# 47            4            NaN              36    6/1/2015     7/25/2021
# 48            3        Married              27    6/1/2015     3/25/2021
# 49            1        Married              22   8/24/2015     5/31/2021
#
#       Status Inactive_Date Reporting_emp_1 Reporting_emp_2  \
# 0     Active            \N              \N              \N
# 1     Active            \N              \N              \N
# 2   Inactive     6/28/2021              \N              \N
# 3   Inactive     1/31/2022              \N              \N
# 4     Active            \N              \N              \N
# 5   Inactive     8/31/2020              \N              \N
# 6     Active    0000-00-00             945              \N
# 7     Active            \N              \N              \N
# 8     Active            \N              \N              \N
# 9   Inactive     1/31/2022              \N              \N
# 10  Inactive      5/5/2021              \N              \N
# 11    Active    0000-00-00              \N              \N
# 12  Inactive     5/23/2021              \N              \N
# 13  Inactive     9/10/2020              \N              \N
# 14  Inactive     5/21/2020              \N              \N
# 15  Inactive     4/30/2021              \N              \N
# 16  Inactive     9/27/2020              \N              \N
# 17    Active    0000-00-00              \N              \N
# 18    Active    0000-00-00              \N              \N
# 19    Active            \N             624              \N
# 20  Inactive     7/28/2020              \N              \N
# 21  Inactive     6/30/2020              \N              \N
# 22    Active            \N              \N              \N
# 23    Active            \N             624              \N
# 24    Active            \N              \N              \N
# 25    Active            \N              \N              \N
# 26    Active            \N              \N              \N
# 27  Inactive     3/30/2020              \N              \N
# 28    Active    0000-00-00              \N              \N
# 29  Inactive    11/14/2019              \N              \N
# 30    Active            \N            2709              \N
# 31    Active            \N             393              \N
# 32  Inactive    12/17/2021              \N              \N
# 33    Active            \N              \N              \N
# 34  Inactive     8/31/2021              \N              \N
# 35    Active    0000-00-00              \N              \N
# 36    Active    0000-00-00              \N              \N
# 37  Inactive     8/31/2020              \N              \N
# 38  Inactive     8/28/2020              \N              \N
# 39    Active    0000-00-00             673              \N
# 40  Inactive     12/5/2019              \N              \N
# 41  Inactive     6/22/2020              \N              \N
# 42    Active    0000-00-00              \N              \N
# 43  Inactive     5/30/2021              \N              \N
# 44    Active    0000-00-00              \N              \N
# 45  Inactive     8/31/2021              \N              \N
# 46  Inactive     10/6/2020              \N              \N
# 47  Inactive     7/25/2021              \N              \N
# 48  Inactive     3/25/2021              \N              \N
# 49  Inactive     5/31/2021              \N              \N
#
#    Employment_Category Employment_Type  Religion               Designation  \
# 0                Staff       Permanant  Buddhist                    Driver
# 1                Staff       Permanant  Buddhist                    Driver
# 2                Staff       Permanant  Buddhist             Account Clerk
# 3                Staff       Permanant  Catholic        Purchasing Officer
# 4                Staff       Permanant  Buddhist              Store Keeper
# 5                Staff       Permanant  Buddhist         Technical Officer
# 6                Staff       Permanant  Buddhist         Technical Officer
# 7                Staff       Permanant  Buddhist      Project Coordinator
# 8                Staff       Permanant  Buddhist             Account Clerk
# 9                Staff       Permanant  Buddhist               Electrician
# 10          Management       Permanant  Buddhist         Transport Officer
# 11               Staff       Permanant     Hindu              Store Keeper
# 12               Staff       Permanant  Buddhist                    Driver
# 13               Staff       Permanant  Buddhist            Operator - JCB
# 14               Staff       Permanant  Buddhist             Driver - Boom
# 15          Management  Contarct Basis  Buddhist      Construction Manager
# 16               Staff  Contarct Basis  Buddhist          Operator - Crane
# 17               Staff  Contarct Basis  Buddhist        Operator-Excavator
# 18               Staff  Contarct Basis  Buddhist              Store Keeper
# 19               Staff  Contarct Basis    Muslim               Draughtsman
# 20               Staff  Contarct Basis  Buddhist             Site Engineer
# 21               Staff  Contarct Basis  Buddhist                Supervisor
# 22               Staff  Contarct Basis  Buddhist                    Driver
# 23               Staff  Contarct Basis    Muslim         Technical Officer
# 24               Staff  Contarct Basis  Buddhist                    Driver
# 25               Staff  Contarct Basis  Buddhist         Quantity Surveyor
# 26               Staff  Contarct Basis  Buddhist  Junior Technical Officer
# 27               Staff  Contarct Basis  Buddhist         Technical Officer
# 28               Staff  Contarct Basis  Buddhist                    Driver
# 29               Staff  Contarct Basis  Buddhist            Driver-Tractor
# 30               Staff  Contarct Basis    Muslim         Technical Officer
# 31               Staff  Contarct Basis    Muslim           Project Manager
# 32               Staff  Contarct Basis  Buddhist          Operator - Crane
# 33               Staff  Contarct Basis  Buddhist         Operator - Loader
# 34               Staff  Contarct Basis     Hindu                Supervisor
# 35               Staff  Contarct Basis     Hindu                Supervisor
# 36               Staff  Contarct Basis  Buddhist              Store Keeper
# 37               Staff  Contarct Basis  Buddhist                    Driver
# 38               Staff  Contarct Basis  Buddhist            Operator - JCB
# 39               Staff  Contarct Basis  Buddhist        Engineer Assistant
# 40               Staff  Contarct Basis  Buddhist                Supervisor
# 41               Staff  Contarct Basis     Hindu         Quantity Surveyor
# 42               Staff  Contarct Basis  Buddhist         Quantity Surveyor
# 43               Staff  Contarct Basis  Buddhist            Moter Mechanic
# 44               Staff  Contarct Basis  Buddhist                    Driver
# 45               Staff  Contarct Basis  Buddhist        Operator-Excavator
# 46               Staff  Contarct Basis     Hindu            Lab Technician
# 47               Staff  Contarct Basis  Catholic        Engineer Assistant
# 48               Staff  Contarct Basis     Hindu                Supervisor
# 49               Staff  Contarct Basis  Buddhist         Technical Officer
#
#    Year_of_Birth
# 0           1965
# 1           1973
# 2           1974
# 3           1974
# 4           1980
# 5           1962
# 6           1969
# 7           1981
# 8           1974
# 9           1967
# 10          1976
# 11          1986
# 12          1975
# 13          1984
# 14          1973
# 15          1963
# 16          1981
# 17          1990
# 18          1961
# 19          1982
# 20          1965
# 21          1991
# 22          1978
# 23          1982
# 24          1994
# 25          1989
# 26          1986
# 27          1989
# 28          1994
# 29          1960
# 30          1989
# 31          1965
# 32          1993
# 33          1993
# 34          1989
# 35          1988
# 36          1972
# 37          1995
# 38          1992
# 39          1987
# 40        '0000'
# 41          1990
# 42          1990
# 43          1995
# 44        '0000'
# 45          1997
# 46          1985
# 47          1982
# 48          1986
# 49          1988

# %%
# Count the number of missing values in each column
missing_values = chatterbox.isnull().sum()
print(missing_values)
# Out:
# Employee_No             0
# Employee_Code           0
# Name                    0
# Title                   0
# Gender                  0
# Religion_ID             0
# Marital_Status         67
# Designation_ID          0
# Date_Joined             0
# Date_Resigned           0
# Status                  0
# Inactive_Date           0
# Reporting_emp_1         0
# Reporting_emp_2         0
# Employment_Category     0
# Employment_Type         0
# Religion                0
# Designation             0
# Year_of_Birth           0
# dtype: int64

# %% [markdown]
# *   There are missing values present in the type of '\N', '0000' in Year_of_birth column and '0000-00-00' in Date_Resigned and Inactive_Date columns.

# %%
# Convert each of these values to NaN.
chatterbox = chatterbox.where(chatterbox != '\\N')
chatterbox.Year_of_Birth = chatterbox.Year_of_Birth.where(chatterbox.Year_of_Birth != "'0000'")
chatterbox.Date_Resigned = chatterbox.Date_Resigned.where(chatterbox.Date_Resigned != '0000-00-00')
chatterbox.Inactive_Date = chatterbox.Inactive_Date.where(chatterbox.Inactive_Date != '0000-00-00')

print(chatterbox.isnull().sum())
# Out:
# Employee_No              0
# Employee_Code            0
# Name                     0
# Title                    0
# Gender                   0
# Religion_ID              0
# Marital_Status          67
# Designation_ID           0
# Date_Joined              0
# Date_Resigned          456
# Status                   0
# Inactive_Date          233
# Reporting_emp_1        936
# Reporting_emp_2        997
# Employment_Category      0
# Employment_Type          0
# Religion                 0
# Designation              0
# Year_of_Birth          103
# dtype: int64

# %% [markdown]
# *   Reporting_emp_1, Reporting_emp_2 column has a significant number of missing values.So it is not important for our analysis. we can choose to remove it this entirely.

# %%
# # Remove two columns from the dataset
# columns_to_remove = ['Reporting_emp_1','Reporting_emp_2']
# chatterbox = chatterbox.drop(columns=columns_to_remove)

# %% [markdown]
# 4. Handling Missing Values of Year of Birth Column

# %% [markdown]
# *   Lets find meadian,mode and mean using given datas

# %%
# convert the 'Year_of_Birth' column to numeric values and store them as nullable integers.

chatterbox['Year_of_Birth'] = pd.to_numeric(chatterbox['Year_of_Birth'], errors='coerce')
chatterbox['Year_of_Birth'] = chatterbox['Year_of_Birth'].astype('Int64')

# %%
# temp DataFrame will be a modified version of 'chatterbox' with the rows containing missing values in the 'Year_of_Birth' column removed.
temp =  chatterbox.copy()
temp = temp.dropna(subset=['Year_of_Birth'])

temp.shape
# Out:
# (894, 19)

# %%
plt.hist(temp['Year_of_Birth'], bins=50)
plt.xlabel('Year of Birth')
plt.ylabel('Frequency')
plt.title('Distribution of Year of Birth')

# Add vertical lines for mean, median, and mode
mean_val = temp['Year_of_Birth'].mean()
median_val = temp['Year_of_Birth'].median()
mode_val = temp['Year_of_Birth'].mode()[0]

plt.axvline(mean_val, color='k', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(median_val, color='b', linestyle='dashed', linewidth=1, label='Median')
plt.axvline(mode_val, color='g', linestyle='dashed', linewidth=1, label='Mode')

# Display mean, median, and mode as text
plt.text(mean_val, np.max(plt.hist(temp['Year_of_Birth'], bins=50)[0]), f"Mean: {mean_val:.2f}", color='k')
plt.text(median_val, np.max(plt.hist(temp['Year_of_Birth'], bins=50)[0])*0.9, f"Median: {median_val}", color='b')
plt.text(mode_val, np.max(plt.hist(temp['Year_of_Birth'], bins=50)[0])*0.8, f"Mode: {mode_val}", color='g')

plt.legend()
plt.show()

# %% [markdown]
# *   this has negative skewness shape.so use Median to fill null vales.

# %%
chatterbox['Year_of_Birth'] = chatterbox['Year_of_Birth'].fillna(chatterbox['Year_of_Birth'].median())

# %% [markdown]
# 5. Handling Missing Values of  Marital Status Column

# %%
# find out what data is present in a column
unique_values = chatterbox['Marital_Status'].unique()
print(unique_values)
# Out:
# ['Married' 'Single' nan]

# %%
# temp1 DataFrame will be a modified version of 'chatterbox' with the rows containing missing values in the 'Marital_Status' column removed.
temp1 = chatterbox.copy()
temp1 = temp1.dropna(subset=['Marital_Status'])

# %%
# 'Year_of_Birth' column against the 'Marital_Status'

plt.scatter(temp1['Year_of_Birth'], temp1['Marital_Status'])
plt.xlabel('Year of Birth')
plt.ylabel('Marital Status')
plt.title('Marital Status over Year of Birth')

# Add vertical lines for the mean 'Year_of_Birth' for each 'Marital_Status' category
plt.axvline(x=temp1[temp1['Marital_Status'] == 'Single']['Year_of_Birth'].mean(), color='r', linestyle='dashed', label='Single Mean')
plt.axvline(x=temp1[temp1['Marital_Status'] == 'Married']['Year_of_Birth'].mean(), color='k', linestyle='dashed', label='Married Mean')

plt.legend()  # Display the legend
plt.show()

# %% [markdown]
# *   calculates the mean of the 'Year_of_Birth' values for the 'Single' and 'Married' categories in the 'temp1' DataFrame. It then uses this mean value to fill the missing values in the 'Marital_Status' column of the 'chatterbox' DataFrame.

# %%
# Calculate the mean of 'Year_of_Birth' for 'Single' and 'Married' categories
meanYear = (temp1[temp1['Marital_Status'] == 'Single']['Year_of_Birth'].mean() +
            temp1[temp1['Marital_Status'] == 'Married']['Year_of_Birth'].mean()) / 2

# Fill missing values in 'Marital_Status' based on the condition using 'meanYear'
chatterbox['Marital_Status'] = chatterbox['Marital_Status'].fillna(chatterbox['Year_of_Birth'].apply(lambda x: 'Single' if x > meanYear else 'Married'))

# %%
chatterbox.head(50)
# Out:
#     Employee_No  Employee_Code                   Name Title  Gender  \
# 0           347              6      Myrl Bechtelar MD    Mr    Male
# 1           348             33           Francis Mraz    Mr    Male
# 2           349             53      Mr Emmet Blick Jr    Mr    Male
# 3           351             77    Mr Nelson Braun PhD    Ms  Female
# 4           352             88       Maximillian Hand    Mr    Male
# 5           353            155           Zena Nicolas    Mr    Male
# 6           354            181       Coralie Bernhard    Mr    Male
# 7           355            192              Josh Roob    Mr    Male
# 8           356            283           Ernest Upton    Ms  Female
# 9           359            529     Sydney Oberbrunner    Mr    Male
# 10          360            573         Angeline Yundt    Mr    Male
# 11          361            596  Prof Karlie Bauch III    Mr    Male
# 12          363            691       Leonel Romaguera    Mr    Male
# 13          365            759      Sidney Macejkovic    Mr    Male
# 14          366            900     Prof Jerod Pfeffer    Mr    Male
# 15          371           1084   Ignatius Volkman DDS    Ms  Female
# 16          372           1086        Doyle Hettinger    Mr    Male
# 17          373           1093           Izaiah Berge    Mr    Male
# 18          376           1154  Prof Arden Jacobs III    Mr    Male
# 19          377           1275  Shaylee Schroeder III    Mr    Male
# 20          378           1290          Raymond Bogan    Mr    Male
# 21          379           1329            Kayden Rice    Mr    Male
# 22          380           1336          Macey Simonis    Mr    Male
# 23          381           1373          Jayde Witting    Mr    Male
# 24          383           1405        Sylvan Gislason    Mr    Male
# 25          384           1425     Dr Kennedy Ryan MD    Mr    Male
# 26          385           1472    Tillman Greenfelder    Mr    Male
# 27          388           1573            Hanna Wyman    Mr    Male
# 28          389           1587           Tessie Fadel    Mr    Male
# 29          391           1610           Orval Hessel    Mr    Male
# 30          392           1620       Katelin Thompson    Mr    Male
# 31          393           1653         Savanna Spinka    Mr    Male
# 32          394           1730        Carley Bogisich    Mr    Male
# 33          396           1769         Jaquelin Block    Mr    Male
# 34          399           1870         Garland Feeney    Mr    Male
# 35          400           1872          Elody Waelchi    Mr    Male
# 36          401           1888             Nola Grant    Mr    Male
# 37          402           1900          Macie Kuvalis    Mr    Male
# 38          403           2009          Julie Osinski    Mr    Male
# 39          404           2026            Jody Stokes    Mr    Male
# 40          405           2034          Scottie Ratke    Mr    Male
# 41          407           2151       Braulio Pagac IV    Mr    Male
# 42          408           2186               Jon Kuhn    Mr    Male
# 43          410           2284          Ally Nikolaus    Mr    Male
# 44          411           2301      Jesus Dietrich Sr    Mr    Male
# 45          413           2313            Addie Purdy    Mr    Male
# 46          414           2333     Noelia Roberts DDS    Mr    Male
# 47          415           2334        Isabella Brakus    Mr    Male
# 48          416           2337          Bo Schaefer I    Mr    Male
# 49          419           2421          Ms Jany Lemke    Mr    Male
#
#     Religion_ID Marital_Status  Designation_ID Date_Joined Date_Resigned  \
# 0             1        Married              24   12/8/1993           NaN
# 1             1        Married              24   3/14/1995           NaN
# 2             1        Married              23   1/27/1988     6/28/2021
# 3             4        Married              40   10/1/1999     1/31/2022
# 4             1        Married               7   1/26/2001           NaN
# 5             1        Married              22   9/29/2003           NaN
# 6             1        Married              22  11/10/2003           NaN
# 7             1        Married             126   2/16/2004           NaN
# 8             1         Single              23    6/1/2005           NaN
# 9             1        Married              41    7/1/2006     1/31/2022
# 10            1        Married              42   8/29/2006      5/5/2021
# 11            3         Single               7   11/1/2006           NaN
# 12            1        Married              24   5/25/2007     5/23/2021
# 13            1        Married              43  11/12/2007           NaN
# 14            1        Married              44  11/15/2008           NaN
# 15            1         Single              45    8/2/2010     4/30/2021
# 16            1        Married              46    8/5/2010           NaN
# 17            1        Married              35  10/26/2010           NaN
# 18            1        Married               7   3/24/2011           NaN
# 19            5         Single              48   11/3/2011           NaN
# 20            1        Married              33  11/21/2011           NaN
# 21            1         Single              27   1/25/2012           NaN
# 22            1        Married              24   1/29/2012           NaN
# 23            5        Married              22   3/17/2012           NaN
# 24            1        Married              24   5/21/2012           NaN
# 25            1        Married               8    6/5/2012           NaN
# 26            1        Married              49    7/6/2012           NaN
# 27            1        Married              22  11/18/2012           NaN
# 28            1        Married              24  12/14/2012           NaN
# 29            1        Married              37   1/24/2013           NaN
# 30            5        Married              22    2/5/2013           NaN
# 31            5        Married               6    4/1/2013           NaN
# 32            1        Married              46   6/27/2013    12/17/2021
# 33            1         Single              67   8/21/2013           NaN
# 34            3        Married              27   1/28/2014     8/31/2021
# 35            3         Single              27   1/24/2014           NaN
# 36            1        Married               7   2/25/2014           NaN
# 37            1         Single              24   2/22/2014           NaN
# 38            1        Married              43    5/3/2014           NaN
# 39            1         Single              36    6/4/2014           NaN
# 40            1         Single              27    6/9/2014           NaN
# 41            3         Single               8   9/17/2014           NaN
# 42            1         Single               8   10/1/2014           NaN
# 43            1         Single              52    2/5/2015     5/30/2021
# 44            1        Married              24   4/28/2015           NaN
# 45            1         Single              35    5/1/2015           NaN
# 46            3         Single              54    6/2/2016           NaN
# 47            4        Married              36    6/1/2015     7/25/2021
# 48            3        Married              27    6/1/2015     3/25/2021
# 49            1        Married              22   8/24/2015     5/31/2021
#
#       Status Inactive_Date Reporting_emp_1 Reporting_emp_2  \
# 0     Active           NaN             NaN             NaN
# 1     Active           NaN             NaN             NaN
# 2   Inactive     6/28/2021             NaN             NaN
# 3   Inactive     1/31/2022             NaN             NaN
# 4     Active           NaN             NaN             NaN
# 5   Inactive     8/31/2020             NaN             NaN
# 6     Active           NaN             945             NaN
# 7     Active           NaN             NaN             NaN
# 8     Active           NaN             NaN             NaN
# 9   Inactive     1/31/2022             NaN             NaN
# 10  Inactive      5/5/2021             NaN             NaN
# 11    Active           NaN             NaN             NaN
# 12  Inactive     5/23/2021             NaN             NaN
# 13  Inactive     9/10/2020             NaN             NaN
# 14  Inactive     5/21/2020             NaN             NaN
# 15  Inactive     4/30/2021             NaN             NaN
# 16  Inactive     9/27/2020             NaN             NaN
# 17    Active           NaN             NaN             NaN
# 18    Active           NaN             NaN             NaN
# 19    Active           NaN             624             NaN
# 20  Inactive     7/28/2020             NaN             NaN
# 21  Inactive     6/30/2020             NaN             NaN
# 22    Active           NaN             NaN             NaN
# 23    Active           NaN             624             NaN
# 24    Active           NaN             NaN             NaN
# 25    Active           NaN             NaN             NaN
# 26    Active           NaN             NaN             NaN
# 27  Inactive     3/30/2020             NaN             NaN
# 28    Active           NaN             NaN             NaN
# 29  Inactive    11/14/2019             NaN             NaN
# 30    Active           NaN            2709             NaN
# 31    Active           NaN             393             NaN
# 32  Inactive    12/17/2021             NaN             NaN
# 33    Active           NaN             NaN             NaN
# 34  Inactive     8/31/2021             NaN             NaN
# 35    Active           NaN             NaN             NaN
# 36    Active           NaN             NaN             NaN
# 37  Inactive     8/31/2020             NaN             NaN
# 38  Inactive     8/28/2020             NaN             NaN
# 39    Active           NaN             673             NaN
# 40  Inactive     12/5/2019             NaN             NaN
# 41  Inactive     6/22/2020             NaN             NaN
# 42    Active           NaN             NaN             NaN
# 43  Inactive     5/30/2021             NaN             NaN
# 44    Active           NaN             NaN             NaN
# 45  Inactive     8/31/2021             NaN             NaN
# 46  Inactive     10/6/2020             NaN             NaN
# 47  Inactive     7/25/2021             NaN             NaN
# 48  Inactive     3/25/2021             NaN             NaN
# 49  Inactive     5/31/2021             NaN             NaN
#
#    Employment_Category Employment_Type  Religion               Designation  \
# 0                Staff       Permanant  Buddhist                    Driver
# 1                Staff       Permanant  Buddhist                    Driver
# 2                Staff       Permanant  Buddhist             Account Clerk
# 3                Staff       Permanant  Catholic        Purchasing Officer
# 4                Staff       Permanant  Buddhist              Store Keeper
# 5                Staff       Permanant  Buddhist         Technical Officer
# 6                Staff       Permanant  Buddhist         Technical Officer
# 7                Staff       Permanant  Buddhist      Project Coordinator
# 8                Staff       Permanant  Buddhist             Account Clerk
# 9                Staff       Permanant  Buddhist               Electrician
# 10          Management       Permanant  Buddhist         Transport Officer
# 11               Staff       Permanant     Hindu              Store Keeper
# 12               Staff       Permanant  Buddhist                    Driver
# 13               Staff       Permanant  Buddhist            Operator - JCB
# 14               Staff       Permanant  Buddhist             Driver - Boom
# 15          Management  Contarct Basis  Buddhist      Construction Manager
# 16               Staff  Contarct Basis  Buddhist          Operator - Crane
# 17               Staff  Contarct Basis  Buddhist        Operator-Excavator
# 18               Staff  Contarct Basis  Buddhist              Store Keeper
# 19               Staff  Contarct Basis    Muslim               Draughtsman
# 20               Staff  Contarct Basis  Buddhist             Site Engineer
# 21               Staff  Contarct Basis  Buddhist                Supervisor
# 22               Staff  Contarct Basis  Buddhist                    Driver
# 23               Staff  Contarct Basis    Muslim         Technical Officer
# 24               Staff  Contarct Basis  Buddhist                    Driver
# 25               Staff  Contarct Basis  Buddhist         Quantity Surveyor
# 26               Staff  Contarct Basis  Buddhist  Junior Technical Officer
# 27               Staff  Contarct Basis  Buddhist         Technical Officer
# 28               Staff  Contarct Basis  Buddhist                    Driver
# 29               Staff  Contarct Basis  Buddhist            Driver-Tractor
# 30               Staff  Contarct Basis    Muslim         Technical Officer
# 31               Staff  Contarct Basis    Muslim           Project Manager
# 32               Staff  Contarct Basis  Buddhist          Operator - Crane
# 33               Staff  Contarct Basis  Buddhist         Operator - Loader
# 34               Staff  Contarct Basis     Hindu                Supervisor
# 35               Staff  Contarct Basis     Hindu                Supervisor
# 36               Staff  Contarct Basis  Buddhist              Store Keeper
# 37               Staff  Contarct Basis  Buddhist                    Driver
# 38               Staff  Contarct Basis  Buddhist            Operator - JCB
# 39               Staff  Contarct Basis  Buddhist        Engineer Assistant
# 40               Staff  Contarct Basis  Buddhist                Supervisor
# 41               Staff  Contarct Basis     Hindu         Quantity Surveyor
# 42               Staff  Contarct Basis  Buddhist         Quantity Surveyor
# 43               Staff  Contarct Basis  Buddhist            Moter Mechanic
# 44               Staff  Contarct Basis  Buddhist                    Driver
# 45               Staff  Contarct Basis  Buddhist        Operator-Excavator
# 46               Staff  Contarct Basis     Hindu            Lab Technician
# 47               Staff  Contarct Basis  Catholic        Engineer Assistant
# 48               Staff  Contarct Basis     Hindu                Supervisor
# 49               Staff  Contarct Basis  Buddhist         Technical Officer
#
#     Year_of_Birth
# 0            1965
# 1            1973
# 2            1974
# 3            1974
# 4            1980
# 5            1962
# 6            1969
# 7            1981
# 8            1974
# 9            1967
# 10           1976
# 11           1986
# 12           1975
# 13           1984
# 14           1973
# 15           1963
# 16           1981
# 17           1990
# 18           1961
# 19           1982
# 20           1965
# 21           1991
# 22           1978
# 23           1982
# 24           1994
# 25           1989
# 26           1986
# 27           1989
# 28           1994
# 29           1960
# 30           1989
# 31           1965
# 32           1993
# 33           1993
# 34           1989
# 35           1988
# 36           1972
# 37           1995
# 38           1992
# 39           1987
# 40           1987
# 41           1990
# 42           1990
# 43           1995
# 44           1987
# 45           1997
# 46           1985
# 47           1982
# 48           1986
# 49           1988

# %% [markdown]
#  6. identify whether there are data quality issues

# %% [markdown]
# find duplicates in Employee_No	,Employee_Code	,Name columns of a DataFrame.

# %%
column_has_duplicates = chatterbox['Name'].duplicated().any()

if column_has_duplicates:
    print("The column has duplicates.")
else:
    print("The column does not have duplicates.")
# Out:
# The column does not have duplicates.

# %%
column_has_duplicates = chatterbox['Employee_No'].duplicated().any()

if column_has_duplicates:
    print("The column has duplicates.")
else:
    print("The column does not have duplicates.")
# Out:
# The column does not have duplicates.

# %%
column_has_duplicates = chatterbox['Employee_Code'].duplicated().any()

if column_has_duplicates:
    print("The column has duplicates.")
else:
    print("The column does not have duplicates.")
# Out:
# The column does not have duplicates.

# %%
chatterbox.to_csv('employee_preprocess_200607V.csv', index=False)
